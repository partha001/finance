# %%
# %matplotlib inline 
import pandas as pd
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# '/app/jupyternotebooks'

# %%
imported_assets = pd.read_csv("../test.csv")
imported_assets = imported_assets

# %%
print(type(imported_assets))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
imported_assets = imported_assets[imported_assets["username"]=="partha"]
imported_assets
# Out:
#       id username assettype           assetname  amount valuationdate
# 0    266   partha      cash                cash     0.0    2023-04-01
# 1      1   partha    equity      zerodha_equity  1565.0    2022-01-01
# 2      6   partha    equity     angelone_equity   225.0    2022-01-01
# 3     11   partha    equity  indmoney_us_stocks     0.0    2022-01-01
# 4     12   partha    equity       upstox_equity     0.0    2022-01-01
# ..   ...      ...       ...                 ...     ...           ...
# 415  373   partha    crypto               vauld     3.0    2023-10-01
# 416  391   partha    crypto              wazirx     9.0    2023-11-01
# 417  392   partha    crypto               vauld     3.0    2023-11-01
# 418  410   partha    crypto              wazirx    13.0    2023-12-01
# 419  411   partha    crypto               vauld     3.0    2023-12-01
#
# [360 rows x 6 columns]

# %%
#imported_assets.plot(x='valuationdate',y='amount')
imported_assets["valuationdate"] = pd.to_datetime(imported_assets["valuationdate"])

imported_assets.pivot(index="valuationdate", columns="assetname", values="amount").plot()


plt.show()
plt.close()

# %%
pivotedAssets =imported_assets.pivot(index="valuationdate", columns="assetname", values=['amount'])

pivotedAssets
# Out:
#                      amount                                            \
# assetname     angelone_cash angelone_equity axis_mf   cash groww_cash
# valuationdate
# 2022-01-01              0.0           225.0   620.0    0.0       10.0
# 2022-02-01              7.0           218.0   630.0    0.0        0.0
# 2022-03-01              0.0           191.0   611.0    0.0       50.0
# 2022-04-01              8.0           143.0   620.0    0.0       20.0
# 2022-05-01              8.0           143.0   620.0    0.0       20.0
# 2022-06-01              8.0           143.0   620.0    0.0       20.0
# 2022-07-01              0.0           166.0   674.0    0.0       50.0
# 2022-08-01              0.0           106.0   794.0    0.0       10.0
# 2022-09-01             14.0           116.0   827.0    0.0        0.0
# 2022-10-01             14.0           116.0   862.0    0.0        0.0
# 2022-11-01              1.0           123.0   880.0  210.0        0.0
# 2022-12-01              8.0           100.0   943.0  160.0        0.0
# 2023-01-01              4.0           116.0   960.0  100.0        0.0
# 2023-02-01              0.0           119.0   985.0    0.0        0.0
# 2023-03-01              0.0           115.0   971.0  102.0        0.0
# 2023-04-01              4.0           152.0  1024.0    0.0        0.0
# 2023-05-01              0.0           163.0  1001.0  453.0        0.0
# 2023-06-01              0.0           180.0  1031.0  185.0        0.0
# 2023-07-01              0.0           200.0  1061.0    0.0        0.0
# 2023-08-01              3.0           225.0  1035.0  280.0        0.0
# 2023-09-01              3.2           229.0  1081.0   34.0        0.0
# 2023-10-01              0.0           239.0  1039.0   85.0        0.0
# 2023-11-01              6.0           273.0  1089.0   60.0        0.0
# 2023-12-01             20.0           288.0  1169.0  295.0        0.0
#
#                                                                       \
# assetname     groww_mf indmoney_us_stocks    lic      pf upstox_cash
# valuationdate
# 2022-01-01      1275.0               0.00  123.0   921.0         0.0
# 2022-02-01      1257.0               0.00    0.0   944.0         0.0
# 2022-03-01      1302.0              10.00    0.0   967.0         0.0
# 2022-11-01         662.0
# 2022-12-01         669.0
# 2023-01-01         660.0
# 2023-02-01         661.0
# 2023-03-01         649.0
# 2023-04-01         660.0
# 2023-05-01         710.0
# 2023-06-01         735.0
# 2023-07-01         753.0
# 2023-08-01         759.0
# 2023-09-01         791.0
# 2023-10-01         768.0
# 2023-11-01         817.0
# 2023-12-01         859.0

# %%
pivotedAssets.dtypes
# df1 = pivotedAssets.assign(total=lambda x: x.zerodha_mf + zerodha_equity)
# df1


# fig, ax = plt.subplots(figsize=(10,6))

# plt.show()
# plt.close()
# Out:
#         assetname
# amount  angelone_cash         float64
#         angelone_equity       float64
#         axis_mf               float64
#         cash                  float64
#         groww_cash            float64
#         groww_mf              float64
#         indmoney_us_stocks    float64
#         lic                   float64
#         pf                    float64
#         upstox_cash           float64
#         upstox_equity         float64
#         vauld                 float64
#         wazirx                float64
#         zerodha_cash          float64
#         zerodha_equity        float64
#         zerodha_mf            float64
# dtype: object

# %%
dftemp = pivotedAssets
dftemp["total"] = dftemp.groupby(level=0, axis=1).sum()
#dftemp["total"] = dftemp.T.groupby(level=0).sum()
dftemp
# Out:
# /tmp/ipykernel_1465/2259910694.py:2: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   dftemp["total"] = dftemp.groupby(level=0, axis=1).sum()
#                      amount                                            \
# assetname     angelone_cash angelone_equity axis_mf   cash groww_cash
# valuationdate
# 2022-01-01              0.0           225.0   620.0    0.0       10.0
# 2022-02-01              7.0           218.0   630.0    0.0        0.0
# 2022-03-01              0.0           191.0   611.0    0.0       50.0
# 2022-04-01              8.0           143.0   620.0    0.0       20.0
# 2022-05-01              8.0           143.0   620.0    0.0       20.0
# 2022-06-01              8.0           143.0   620.0    0.0       20.0
# 2022-07-01              0.0           166.0   674.0    0.0       50.0
# 2022-08-01              0.0           106.0   794.0    0.0       10.0
# 2022-09-01             14.0           116.0   827.0    0.0        0.0
# 2022-10-01             14.0           116.0   862.0    0.0        0.0
# 2022-11-01              1.0           123.0   880.0  210.0        0.0
# 2022-12-01              8.0           100.0   943.0  160.0        0.0
# 2023-01-01              4.0           116.0   960.0  100.0        0.0
# 2023-02-01              0.0           119.0   985.0    0.0        0.0
# 2023-03-01              0.0           115.0   971.0  102.0        0.0
# 2023-04-01              4.0           152.0  1024.0    0.0        0.0
# 2023-05-01              0.0           163.0  1001.0  453.0        0.0
# 2023-06-01              0.0           180.0  1031.0  185.0        0.0
# 2023-07-01              0.0           200.0  1061.0    0.0        0.0
# 2023-08-01              3.0           225.0  1035.0  280.0        0.0
# 2023-09-01              3.2           229.0  1081.0   34.0        0.0
# 2023-10-01              0.0           239.0  1039.0   85.0        0.0
# 2023-11-01              6.0           273.0  1089.0   60.0        0.0
# 2023-12-01             20.0           288.0  1169.0  295.0        0.0
#
#                                                                       \
# assetname     groww_mf indmoney_us_stocks    lic      pf upstox_cash
# valuationdate
# 2022-01-01      1275.0               0.00  123.0   921.0         0.0
# 2022-02-01      1257.0               0.00    0.0   944.0         0.0
# 2022-03-01      1302.0              10.00    0.0   967.0         0.0
# 2022-04-01      1284.0               8.00    0.0   990.0        66.0
# 2022-09-01         679.0  6544.00
# 2022-10-01         651.0  6543.00
# 2022-11-01         662.0  6903.00
# 2022-12-01         669.0  7077.00
# 2023-01-01         660.0  6913.00
# 2023-02-01         661.0  6996.00
# 2023-03-01         649.0  7069.00
# 2023-04-01         660.0  7209.00
# 2023-05-01         710.0  8048.00
# 2023-06-01         735.0  8043.00
# 2023-07-01         753.0  8105.53
# 2023-08-01         759.0  8627.90
# 2023-09-01         791.0  8690.10
# 2023-10-01         768.0  8440.20
# 2023-11-01         817.0  9119.00
# 2023-12-01         859.0  9737.00

# %%
dftemp.shape
# Out:
# (24, 17)

# %%
dftemp.columns
# Out:
# MultiIndex([('amount',      'angelone_cash'),
#             ('amount',    'angelone_equity'),
#             ('amount',            'axis_mf'),
#             ('amount',               'cash'),
#             ('amount',         'groww_cash'),
#             ('amount',           'groww_mf'),
#             ('amount', 'indmoney_us_stocks'),
#             ('amount',                'lic'),
#             ('amount',                 'pf'),
#             ('amount',        'upstox_cash'),
#             ('amount',      'upstox_equity'),
#             ('amount',              'vauld'),
#             ('amount',             'wazirx'),
#             ('amount',       'zerodha_cash'),
#             ('amount',     'zerodha_equity'),
#             ('amount',         'zerodha_mf'),
#             ( 'total',                   '')],
#            names=[None, 'assetname'])

# %%
dftemp.ndim
# Out:
# 2

# %%
dftemp.dtypes
# Out:
#         assetname
# amount  angelone_cash         float64
#         angelone_equity       float64
#         axis_mf               float64
#         cash                  float64
#         groww_cash            float64
#         groww_mf              float64
#         indmoney_us_stocks    float64
#         lic                   float64
#         pf                    float64
#         upstox_cash           float64
#         upstox_equity         float64
#         vauld                 float64
#         wazirx                float64
#         zerodha_cash          float64
#         zerodha_equity        float64
#         zerodha_mf            float64
# total                         float64
# dtype: object

# %%
dftemp[('amount', 'angelone_cash')]
# Out:
# valuationdate
# 2022-01-01     0.0
# 2022-02-01     7.0
# 2022-03-01     0.0
# 2022-04-01     8.0
# 2022-05-01     8.0
# 2022-06-01     8.0
# 2022-07-01     0.0
# 2022-08-01     0.0
# 2022-09-01    14.0
# 2022-10-01    14.0
# 2022-11-01     1.0
# 2022-12-01     8.0
# 2023-01-01     4.0
# 2023-02-01     0.0
# 2023-03-01     0.0
# 2023-04-01     4.0
# 2023-05-01     0.0
# 2023-06-01     0.0
# 2023-07-01     0.0
# 2023-08-01     3.0
# 2023-09-01     3.2
# 2023-10-01     0.0
# 2023-11-01     6.0
# 2023-12-01    20.0
# Name: (amount, angelone_cash), dtype: float64

# %%
fig = plt.subplots(figsize=(15, 7))
plt.xlabel('Date', fontsize=15)
plt.ylabel('INR', fontsize=15)
plt.title('assets-vs-time', fontsize=20)
plt.plot(dftemp.index, dftemp[('amount', 'zerodha_equity')], label= 'zerodha_equity')
plt.plot(dftemp.index, dftemp[('amount', 'angelone_equity')], label='angelone_equity')
plt.plot(dftemp.index, dftemp[('amount', 'zerodha_mf')], label='zerodha_mf')
plt.plot(dftemp.index, dftemp[('amount', 'groww_mf')], label='groww_mf')
plt.plot(dftemp.index, dftemp[('total')], label='total')
plt.legend()
plt.savefig('test.png')
plt.show()
plt.close()
